# %% [markdown]
# # INSURANCE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('./insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 1

# %%
data.drop_duplicates(inplace=True)

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10,5))

# %% [markdown]
# ### COUNT PLOT

# %% [markdown]
# sex rate ploted with count plot method
# * male - female ratio nearly eqiual range of 650

# %%
sns.countplot('sex',data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot('children',data=data)
# Out:
# <AxesSubplot:xlabel='children', ylabel='count'>

# %% [markdown]
# childrens values ploted with count plot method
# * most clints dosnt have child

# %%
sns.countplot('region',data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
sns.lineplot(x='sex',y='charges',data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='charges'>

# %%
sns.lineplot(x='age',y='charges',data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.lineplot(x='sex',y='smoker',data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='smoker'>

# %%
sns.countplot('region',data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
sns.lineplot(data.age,data.charges,color='yellow')
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
sns.lineplot(data.age,data.bmi,color='blue')
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
plt.figure(figsize=(15,7))
sns.barplot('age','bmi',data=data)
plt.title('age&bmi')
# Out:
# Text(0.5, 1.0, 'age&bmi')

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='region',y='charges',hue='children',data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
sns.boxplot(x='region',y='charges',hue='children',data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
sns.kdeplot(data=data.charges)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Density'>

# %%
sns.histplot(data.age,color='pink')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data.charges,color='green')
# Out:
# <AxesSubplot:xlabel='charges', ylabel='Count'>

# %%
children_age= data.groupby(['region'])['age'].sum()

# %%
children_age
# Out:
# region
# northeast    12723
# northwest    12720
# southeast    14174
# southwest    12823
# Name: age, dtype: int64

# %%
sns.set_style('ticks')
children_age.plot.pie()
plt.legend()
plt.show()

# %%
children_age.plot.pie(autopct='%1.2f%%')
plt.legend(bbox_to_anchor=(1.5,1),loc='upper left',borderaxespad=0)
plt.show()

# %%
smoker_boy=data.groupby(['sex','smoker'])['age'].sum()

# %%
smoker_boy
# Out:
# sex     smoker
# female  no        21711
#         yes        4440
# male    no        20176
#         yes        6113
# Name: age, dtype: int64

# %%
smoker_boy.plot.pie(autopct='%1.2f%%')
plt.legend(bbox_to_anchor=(1.5,1),loc='upper left',borderaxespad=0)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.pairplot(data)

# %%
plt.figure(figsize=(10,10))
heat_map=data.corr()
sns.heatmap(heat_map,vmin=-1,vmax=1,annot=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
heat_map=data.corr()
sns.heatmap(heat_map,vmin=-1,vmax=1,annot=True, linewidth=30)
plt.show()

# %%
sns.kdeplot(data=data.bmi,color='purple')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Density'>

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
data.value_counts()
# Out:
# age  sex     bmi     children  smoker  region     charges
# 18   female  20.790  0         no      southeast  1607.51010     1
# 48   female  27.360  1         no      northeast  9447.38240     1
#              25.850  3         yes     southeast  24180.93350    1
#              22.800  0         no      southwest  8269.04400     1
# 47   male    47.520  1         no      southeast  8083.91980     1
#                                                                 ..
# 31   female  25.740  0         no      southeast  3756.62160     1
#              23.600  2         no      southwest  4931.64700     1
#              21.755  0         no      northwest  4134.08245     1
# 30   male    44.220  2         no      southeast  4266.16580     1
# 64   male    40.480  0         no      southeast  13831.11520    1
# Length: 1337, dtype: int64

# %%
data.bmi.value_counts()
# Out:
# 32.30    13
# 28.31     9
# 30.80     8
# 31.35     8
# 28.88     8
#          ..
# 46.20     1
# 23.80     1
# 44.77     1
# 32.12     1
# 30.97     1
# Name: bmi, Length: 548, dtype: int64

# %%
smoker_southeast=data.query("smoker=='yes' & sex=='male' &region=='southeast'")

# %%
smoker_southeast
# Out:
#       age   sex    bmi  children smoker     region      charges
# 14     27  male  42.13         0    yes  southeast  39611.75770
# 49     36  male  35.20         1    yes  southeast  38709.17600
# 53     36  male  34.43         0    yes  southeast  37742.57570
# 57     18  male  31.68         2    yes  southeast  34303.16720
# 69     28  male  23.98         3    yes  southeast  17663.14420
# 82     22  male  37.62         1    yes  southeast  37165.16380
# 109    63  male  35.09         0    yes  southeast  47055.53210
# 142    34  male  25.30         2    yes  southeast  18972.49500
# 156    48  male  24.42         0    yes  southeast  21223.67580
# 158    30  male  35.53         0    yes  southeast  36950.25670
# 224    42  male  24.64         0    yes  southeast  19515.54160
# 252    54  male  34.21         2    yes  southeast  44260.74990
# 265    46  male  42.35         3    yes  southeast  46151.12450
# 266    40  male  19.80         1    yes  southeast  17179.52200
# ...

# %%
smoker_southeast.value_counts()
# Out:
# age  sex   bmi    children  smoker  region     charges
# 18   male  31.68  2         yes     southeast  34303.16720    1
# 51   male  42.90  2         yes     southeast  47462.89400    1
# 43   male  20.13  2         yes     southeast  18767.73770    1
#            35.97  3         yes     southeast  42124.51530    1
#            38.06  2         yes     southeast  42560.43040    1
# 45   male  30.36  0         yes     southeast  62592.87309    1
# 46   male  42.35  3         yes     southeast  46151.12450    1
# 47   male  25.41  1         yes     southeast  21978.67690    1
#            36.08  1         yes     southeast  42211.13820    1
#            36.19  0         yes     southeast  41676.08110    1
#            38.94  2         yes     southeast  44202.65360    1
# 48   male  24.42  0         yes     southeast  21223.67580    1
# 51   male  23.21  1         yes     southeast  22218.11490    1
# 52   male  41.80  2         yes     southeast  47269.85400    1
# ...

# %%
age_under20=data.query("age <= 20 & smoker == 'yes' & sex=='female'")

# %%
age_under20
# Out:
#       age     sex    bmi  children smoker     region      charges
# 0      19  female  27.90         0    yes  southwest  16884.92400
# 64     20  female  22.42         0    yes  northwest  14711.74380
# 126    19  female  28.30         0    yes  southwest  17081.08000
# 161    18  female  36.85         0    yes  southeast  36149.48350
# 261    20  female  26.84         1    yes  southeast  17085.26760
# 362    19  female  21.70         0    yes  southwest  13844.50600
# 604    19  female  28.31         0    yes  northwest  17468.98390
# 618    19  female  33.11         0    yes  southeast  34439.85590
# 773    19  female  28.88         0    yes  northwest  17748.50620
# 803    18  female  42.24         0    yes  southeast  38792.68560
# 1139   19  female  32.49         0    yes  northwest  36898.73308
# 1196   19  female  30.02         0    yes  northwest  33307.55080
# 1204   18  female  27.28         3    yes  southeast  18223.45120
# ...

# %%
sns.kdeplot(age_under20.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
data.bmi.value_counts()
# Out:
# 32.30    13
# 28.31     9
# 30.80     8
# 31.35     8
# 28.88     8
#          ..
# 46.20     1
# 23.80     1
# 44.77     1
# 32.12     1
# 30.97     1
# Name: bmi, Length: 548, dtype: int64

# %%
data.sex.value_counts()
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %%
smoker_male1=data.query("sex =='male' & children == 1 & smoker =='yes' " )

# %%
smoker_male1
# Out:
#       age   sex     bmi  children smoker     region      charges
# 34     28  male  36.400         1    yes  southwest  51194.55914
# 38     35  male  36.670         1    yes  northeast  39774.27630
# 49     36  male  35.200         1    yes  southeast  38709.17600
# 52     48  male  28.000         1    yes  southwest  23568.27200
# 82     22  male  37.620         1    yes  southeast  37165.16380
# 105    20  male  28.025         1    yes  northwest  17560.37975
# 123    44  male  31.350         1    yes  northeast  39556.49450
# 266    40  male  19.800         1    yes  southeast  17179.52200
# 297    47  male  25.410         1    yes  southeast  21978.67690
# 338    50  male  32.300         1    yes  northeast  41919.09700
# 422    40  male  32.775         1    yes  northeast  39125.33225
# 444    56  male  26.695         1    yes  northwest  26109.32905
# 475    61  male  28.310         1    yes  northwest  28868.66390
# ...

# %%
smoker_male1.value_counts()
# Out:
# age  sex   bmi     children  smoker  region     charges
# 18   male  27.360  1         yes     northeast  17178.68240    1
# 19   male  26.030  1         yes     northwest  16450.89470    1
# 40   male  32.775  1         yes     northeast  39125.33225    1
# 41   male  35.750  1         yes     southeast  40273.64550    1
# 42   male  26.070  1         yes     southeast  38245.59327    1
# 43   male  34.960  1         yes     northeast  41034.22140    1
# 44   male  31.350  1         yes     northeast  39556.49450    1
# 47   male  25.410  1         yes     southeast  21978.67690    1
#            36.080  1         yes     southeast  42211.13820    1
# 48   male  28.000  1         yes     southwest  23568.27200    1
# 50   male  32.300  1         yes     northeast  41919.09700    1
# 51   male  23.210  1         yes     southeast  22218.11490    1
# 54   male  30.800  1         yes     southeast  41999.52000    1
# 56   male  26.695  1         yes     northwest  26109.32905    1
# ...

# %%
sns.histplot(smoker_male1.age,color=('red'))
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
skk=data.query("age < 30 & sex == 'female'& region =='southwest'| region == 'northwest' ")

# %%
skk
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 7      37  female  27.740         3     no  northwest   7281.50560
# 9      60  female  25.840         0     no  northwest  28923.13692
# ...   ...     ...     ...       ...    ...        ...          ...
# 1324   31    male  25.935         1     no  northwest   4239.89265
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [372 rows x 7 columns]
