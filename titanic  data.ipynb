# %% [markdown]
# # TITANIC

# %%
 import pandas as pd

# %%
data=pd.read_csv('./Titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1       0.0       3
# 1             2       1.0       1
# 2             3       1.0       3
# 3             4       1.0       1
# 4             5       0.0       3
# 5             6       0.0       3
# 6             7       0.0       1
# 7             8       0.0       3
# 8             9       1.0       3
# 9            10       1.0       2
# 10           11       1.0       3
# 11           12       1.0       1
# 12           13       0.0       3
# 13           14       0.0       3
# 14           15       0.0       3
# 15           16       1.0       2
# 16           17       0.0       3
# 17           18       1.0       2
# 18           19       0.0       3
# 19           20       1.0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
data.tail (10)
# Out:
#       PassengerId  Survived  Pclass  \
# 1299         1300       NaN       3
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1299                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 1300                        Peacock, Miss. Treasteall  female   3.0      1
# 1301                           Naughton, Miss. Hannah  female   NaN      0
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
data.sample(20)
# Out:
#       PassengerId  Survived  Pclass  \
# 310           311       1.0       1
# 184           185       1.0       3
# 34             35       0.0       1
# 491           492       0.0       3
# 78             79       1.0       2
# 614           615       0.0       3
# 1288         1289       NaN       1
# 269           270       1.0       1
# 1193         1194       NaN       2
# 1166         1167       NaN       2
# 701           702       1.0       1
# 212           213       0.0       3
# 283           284       1.0       3
# 1054         1055       NaN       3
# 1224         1225       NaN       3
# 790           791       0.0       3
# 275           276       1.0       1
# 1155         1156       NaN       2
# 646           647       0.0       3
# 345           346       1.0       2
#
#                                                    Name     Sex    Age  SibSp  \
# 310                      Hays, Miss. Margaret Bechstein  female  24.00      0
# ...

# %%
data.shape
# Out:
# (1309, 21)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
data.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1046.0   29.881138   14.413493  0.17   21.0000   28.0000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1308.0   33.295479   51.758668  0.00    7.8958   14.4542
# WikiId       1304.0  658.534509  380.377373  1.00  326.7500  661.5000
# Age_wiki     1302.0   29.415829   13.758954  0.17   21.0000   28.0000
# Class        1304.0    2.291411    0.840852  1.00    1.7500    3.0000
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           39.000    80.0000
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
data.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# WikiId          0.381971
# Name_wiki       0.381971
# Age_wiki        0.534759
# Hometown        0.381971
# Boarded         0.381971
# Destination     0.381971
# Lifeboat       61.650115
# Body           90.068755
# Class           0.381971
# dtype: float64

# %%
data.drop(columns=['Body','Lifeboat','Cabin','PassengerId',],inplace=True)

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
data.isnull().mean()*100
# Out:
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Embarked        0.152788
# WikiId          0.381971
# Name_wiki       0.381971
# Age_wiki        0.534759
# Hometown        0.381971
# Boarded         0.381971
# Destination     0.381971
# Class           0.381971
# dtype: float64

# %%
data.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
data.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         2
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.drop(columns=['WikiId','Name_wiki'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         2
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
data.Embarked.fillna('s',inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
Fare_mean=data.Fare.mean()
Fare_mean
# Out:
# 33.2954792813456

# %%
data.Fare.fillna('Fare_mean',inplace=True)

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.Age.value_counts()
# Out:
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: Age, Length: 98, dtype: int64

# %%
data.Age.fillna(24.0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.drop(columns=['Age_wiki'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.Hometown.unique()
# Out:
# array(['Bridgerule, Devon, England', 'New York, New York, US',
#        'Jyväskylä, Finland', 'Scituate, Massachusetts, US',
#        'Birmingham, West Midlands, England', 'Cork, Ireland',
#        'Dorchester, Massachusetts, US', 'Bjuv, Skåne, Sweden',
#        'St. Charles, Illinois, US', 'Zahlé, Lebanon, Ottoman Empire',
#        'Motala, Östergötland, Sweden', 'Youngstown, Ohio, US',
#        'St Austell, Cornwall, England', 'Kisa, Östergötland, Sweden',
#        'Salmunds, Gotland, Sweden', 'Lucknow, British India, UK[note 3]',
#        'Athlone, Westmeath, Ireland', 'Harrow, London, England',
#        'Pittem, Belgium', 'Tebnine, Lebanon',
#        'Liverpool, Merseyside, England, UK', 'London, England, UK',
#        'Massbrook, Mayo, Ireland', 'New Britain, Connecticut, US',
#        'Alseda, Småland, Sweden', 'Hadath, Lebanon',
#        'Winnipeg, Manitoba, Canada', 'Limerick, Limerick, Ireland',
#        'Unknown, Bulgaria', 'Mexico City, Mexico',
# ...

# %%
data.Hometown.value_counts()
# Out:
# New York, New York, US                70
# London, England                       49
# London, England, UK                   30
# Paris, France                         23
# Montreal, Quebec, Canada              20
#                                       ..
# Avaldsnes, Stavanger, Norway           1
# Marbella, Spain                        1
# Västermo, Södermanland, Sweden         1
# Trollhättan, Västergötland, Sweden     1
# Sar'al[81], Syria                      1
# Name: Hometown, Length: 566, dtype: int64

# %%
data.Hometown.fillna('Hometown',inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Hometown         0
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
data.Boarded.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', 'Belfast', nan],
#       dtype=object)

# %%
data.Boarded.value_counts()
# Out:
# Southampton    916
# Cherbourg      259
# Queenstown     119
# Belfast         10
# Name: Boarded, dtype: int64

# %%
data.Boarded.fillna('Boarded',inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Hometown         0
# Boarded          0
# Destination      5
# Class            5
# dtype: int64

# %%
data.Destination.unique()
# Out:
# array(["Qu'Appelle Valley, Saskatchewan, Canada",
#        'New York, New York, US', 'New York City',
#        'Scituate, Massachusetts, US', 'Dorchester, Massachusetts, US',
#        'Chicago, Illinois, US', 'St. Charles, Illinois, US',
#        'Cleveland, Ohio, US', 'San Francisco, US', 'Youngstown, Ohio, US',
#        'Winnipeg, Manitoba, Canada', 'Los Angeles, US',
#        'Rapid City, South Dakota, US', 'Spokane, Washington, US',
#        'Fremont, Ohio, US', 'Michigan City, Indiana, US',
#        'Montreal, Quebec, Canada', 'Toronto, Ontario, Canada',
#        'New Britain, Connecticut, US', 'Worcester, Massachusetts, US',
#        'Mexico City, Mexico', 'Washington, DC, US',
#        'Edgewood, Rhode Island, US', 'Philadelphia, Pennsylvania, US',
#        'Jacksonville, Florida, US', 'Akeley, Minnesota, US',
#        'Salt Lake City, Utah, US', 'Madison, Wisconsin, US',
#        'Cap-Haïtien, Haiti', 'Jersey City, New Jersey, US',
# ...

# %%
data.Destination.value_counts()
# Out:
# New York City                          234
# New York, New York, US                 127
# Chicago, Illinois, US                   75
# Montreal, Quebec, Canada                37
# Detroit, Michigan, US                   28
#                                       ...
# East Bridgewater, Massachusetts, US      1
# Oregon, Wisconsin, US                    1
# Rahway, New Jersey, US                   1
# Stoughton, Massachusetts                 1
# US                                       1
# Name: Destination, Length: 291, dtype: int64

# %%
data.Destination.fillna('New York City' ,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Hometown         0
# Boarded          0
# Destination      0
# Class            5
# dtype: int64

# %%
data.Class.unique()
# Out:
# array([ 3.,  1.,  2., nan])

# %%
data.Class.value_counts()
# Out:
# 3.0    706
# 1.0    326
# 2.0    272
# Name: Class, dtype: int64

# %%
data.Class.fillna(3.0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Hometown         0
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %% [markdown]
# # data.Survived

# %%
data.Survived.unique()
# Out:
# array([ 0.,  1., nan])

# %%
data.Survived.value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
data.Survived.fillna(0.0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Hometown       0
# Boarded        0
# Destination    0
# Class          0
# dtype: int64

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       0.0       3                                 Spector, Mr. Woolf
# 1305       0.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       0.0       3                       Saether, Mr. Simon Sivertsen
# 1307       0.0       3                                Ware, Mr. Frederick
# 1308       0.0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %% [markdown]
# # group by

# %% [markdown]
# ### gender and survived  using groupby

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       0.0       3                                 Spector, Mr. Woolf
# 1305       0.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       0.0       3                       Saether, Mr. Simon Sivertsen
# 1307       0.0       3                                Ware, Mr. Frederick
# 1308       0.0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
sex_surviverd_titanic=data.groupby(["Sex"])['Survived'].sum()

# %%
sex_surviverd_titanic
# Out:
# Sex
# female    233.0
# male      109.0
# Name: Survived, dtype: float64

# %% [markdown]
# ### survived list in p class using groupby

# %%
pclass_survived_titanic=data.groupby(['Pclass'])['Survived'].sum()

# %%
pclass_survived_titanic
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %% [markdown]
# ### boarded from southamton using query

# %%
boarded_from_southamton=data.query("Boarded=='Southampton'")

# %%
boarded_from_southamton
# Out:
#       Survived  Pclass                                             Name  \
# 0          0.0       3                          Braund, Mr. Owen Harris
# 2          1.0       3                           Heikkinen, Miss. Laina
# 3          1.0       1     Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                         Allen, Mr. William Henry
# 6          0.0       1                          McCarthy, Mr. Timothy J
# ...        ...     ...                                              ...
# 1302       0.0       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303       0.0       3                   Henriksson, Miss. Jenny Lovisa
# 1304       0.0       3                               Spector, Mr. Woolf
# 1306       0.0       3                     Saether, Mr. Simon Sivertsen
# 1307       0.0       3                              Ware, Mr. Frederick
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       0.0       3                                 Spector, Mr. Woolf
# 1305       0.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       0.0       3                       Saether, Mr. Simon Sivertsen
# 1307       0.0       3                                Ware, Mr. Frederick
# 1308       0.0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %% [markdown]
# ## survived in age of 24

# %%
age_24_survived = data.query("Age == 24 & Survived == 1.0")
age_24_survived
# Out:
#      Survived  Pclass                                            Name     Sex  \
# 17        1.0       2                    Williams, Mr. Charles Eugene    male
# 19        1.0       3                         Masselmani, Mrs. Fatima  female
# 28        1.0       3                   O'Dwyer, Miss. Ellen "Nellie"  female
# 31        1.0       1  Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 32        1.0       3                        Glynn, Miss. Mary Agatha  female
# ..        ...     ...                                             ...     ...
# 740       1.0       1                     Hawksford, Mr. Walter James    male
# 828       1.0       3                    McCormack, Mr. Thomas Joseph    male
# 839       1.0       1                            Marechal, Mr. Pierre    male
# 849       1.0       1    Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female
# 858       1.0       3           Baclini, Mrs. Solomon (Latifa Qurban)  female
#
# ...

# %% [markdown]
# ### survived in class

# %%
survived_in_class=data.groupby(['Survived'])['Class'].sum()

# %%
survived_in_class
# Out:
# Survived
# 0.0    2337.0
# 1.0     666.0
# Name: Class, dtype: float64

# %% [markdown]
# ### survived in p class-2, gender cound

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       0.0       3                                 Spector, Mr. Woolf
# 1305       0.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       0.0       3                       Saether, Mr. Simon Sivertsen
# 1307       0.0       3                                Ware, Mr. Frederick
# 1308       0.0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
survived_in_pclass_and_gender=data.query("Pclass==3 & Sex== 'female' & Survived==1.0")

# %%
survived_in_pclass_and_gender
# Out:
#      Survived  Pclass                                               Name  \
# 2         1.0       3                             Heikkinen, Miss. Laina
# 8         1.0       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10        1.0       3                    Sandstrom, Miss. Marguerite Rut
# 19        1.0       3                            Masselmani, Mrs. Fatima
# 22        1.0       3                        McGowan, Miss. Anna "Annie"
# ..        ...     ...                                                ...
# 823       1.0       3                                 Moor, Mrs. (Beila)
# 830       1.0       3            Yasbeck, Mrs. Antoni (Selini Alexander)
# 855       1.0       3                         Aks, Mrs. Sam (Leah Rosen)
# 858       1.0       3              Baclini, Mrs. Solomon (Latifa Qurban)
# 875       1.0       3                   Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked  \
# ...

# %%
survived_in_pclass_and_gender=data.groupby(["Pclass"])['Survived'].sum()

# %%
survived_in_pclass_and_gender
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %% [markdown]
# ## non survived data of boarded southamton

# %%
non_survived_southamtin=data.query("Boarded=='Southampton' & Survived==0.0")

# %%
non_survived_southamtin
# Out:
#       Survived  Pclass                                             Name  \
# 0          0.0       3                          Braund, Mr. Owen Harris
# 4          0.0       3                         Allen, Mr. William Henry
# 6          0.0       1                          McCarthy, Mr. Timothy J
# 7          0.0       3                   Palsson, Master. Gosta Leonard
# 12         0.0       3                   Saundercock, Mr. William Henry
# ...        ...     ...                                              ...
# 1302       0.0       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303       0.0       3                   Henriksson, Miss. Jenny Lovisa
# 1304       0.0       3                               Spector, Mr. Woolf
# 1306       0.0       3                     Saether, Mr. Simon Sivertsen
# 1307       0.0       3                              Ware, Mr. Frederick
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %% [markdown]
# ### non survived data of boarded southamton  -age 24& gender-male

# %%
non_survived_southamtin=data.query("Boarded=='Southampton' & Age== 24 & Sex=='male' & Survived==0.0")

# %%
non_survived_southamtin
# Out:
#       Survived  Pclass                            Name   Sex   Age  SibSp  \
# 29         0.0       3             Todoroff, Mr. Lalio  male  24.0      0
# 45         0.0       3        Rogers, Mr. William John  male  24.0      0
# 76         0.0       3               Staneff, Mr. Ivan  male  24.0      0
# 77         0.0       3        Moutal, Mr. Rahamin Haim  male  24.0      0
# 87         0.0       3   Slocovski, Mr. Selman Francis  male  24.0      0
# ...        ...     ...                             ...   ...   ...    ...
# 1248       0.0       3             Lockyer, Mr. Edward  male  24.0      0
# 1275       0.0       2  Wheeler, Mr. Edwin Frederick""  male  24.0      0
# 1277       0.0       3  Aronsson, Mr. Ernst Axel Algot  male  24.0      0
# 1304       0.0       3              Spector, Mr. Woolf  male  24.0      0
# 1307       0.0       3             Ware, Mr. Frederick  male  24.0      0
#
#       Parch           Ticket    Fare Embarked  \
# ...

# %% [markdown]
# ## destination to newyork city,boarded from Southampton
# ### non survived
# ### gender-male with age of 22

# %%
non_survived=data.query("Destination == 'New York City' &Boarded == 'Southampton'& Sex == 'male' & Age == 22 & Survived == 0.0" )

# %%
non_survived
# Out:
#      Survived  Pclass                          Name   Sex   Age  SibSp  Parch  \
# 112       0.0       3        Barton, Mr. David John  male  22.0      0      0
# 225       0.0       3  Berglund, Mr. Karl Ivar Sven  male  22.0      0      0
#
#       Ticket  Fare Embarked                            Hometown      Boarded  \
# 112   324669  8.05        S  Cambridge, Cambridgeshire, England  Southampton
# 225  PP 4348  9.35        S                     Firtby, Finland  Southampton
#
#        Destination  Class
# 112  New York City    3.0
# 225  New York City    3.0

# %% [markdown]
# ## non survived list based on age

# %%
agr_data=data.query("Age == 22 | Age == 24 |Age == 30 & Survived == 0.0")

# %%
agr_data
# Out:
#       Survived  Pclass                             Name     Sex   Age  SibSp  \
# 0          0.0       3          Braund, Mr. Owen Harris    male  22.0      1
# 5          0.0       3                 Moran, Mr. James    male  24.0      0
# 17         1.0       2     Williams, Mr. Charles Eugene    male  24.0      0
# 19         1.0       3          Masselmani, Mrs. Fatima  female  24.0      0
# 26         0.0       3          Emir, Mr. Farred Chehab    male  24.0      0
# ...        ...     ...                              ...     ...   ...    ...
# 1299       0.0       3  Riordan, Miss. Johanna Hannah""  female  24.0      0
# 1301       0.0       3           Naughton, Miss. Hannah  female  24.0      0
# 1304       0.0       3               Spector, Mr. Woolf    male  24.0      0
# 1307       0.0       3              Ware, Mr. Frederick    male  24.0      0
# 1308       0.0       3         Peter, Master. Michael J    male  24.0      1
#
# ...

# %%
agr_data.Age.value_counts()
# Out:
# 24.0    310
# 22.0     43
# 30.0     30
# Name: Age, dtype: int64

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       0.0       3                                 Spector, Mr. Woolf
# 1305       0.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       0.0       3                       Saether, Mr. Simon Sivertsen
# 1307       0.0       3                                Ware, Mr. Frederick
# 1308       0.0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
data.Fare.unique()
# Out:
# array([7.25, 71.2833, 7.925, 53.1, 8.05, 8.4583, 51.8625, 21.075, 11.1333,
#        30.0708, 16.7, 26.55, 31.275, 7.8542, 16.0, 29.125, 13.0, 18.0,
#        7.225, 26.0, 8.0292, 35.5, 31.3875, 263.0, 7.8792, 7.8958, 27.7208,
#        146.5208, 7.75, 10.5, 82.1708, 52.0, 7.2292, 11.2417, 9.475, 21.0,
#        41.5792, 15.5, 21.6792, 17.8, 39.6875, 7.8, 76.7292, 61.9792,
#        27.75, 46.9, 80.0, 83.475, 27.9, 15.2458, 8.1583, 8.6625, 73.5,
#        14.4542, 56.4958, 7.65, 29.0, 12.475, 9.0, 9.5, 7.7875, 47.1,
#        15.85, 34.375, 61.175, 20.575, 34.6542, 63.3583, 23.0, 77.2875,
#        8.6542, 7.775, 24.15, 9.825, 14.4583, 247.5208, 7.1417, 22.3583,
#        6.975, 7.05, 14.5, 15.0458, 26.2833, 9.2167, 79.2, 6.75, 11.5,
#        36.75, 7.7958, 12.525, 66.6, 7.3125, 61.3792, 7.7333, 69.55, 16.1,
#        15.75, 20.525, 55.0, 25.925, 33.5, 30.6958, 25.4667, 28.7125, 0.0,
#        15.05, 39.0, 22.025, 50.0, 8.4042, 6.4958, 10.4625, 18.7875, 31.0,
# ...

# %%
data.Fare.value_counts()
# Out:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
#            ..
# 26.2833     1
# 14.0000     1
# 15.0000     1
# 6.2375      1
# 7.7208      1
# Name: Fare, Length: 282, dtype: int64

# %% [markdown]
# ## survived
# ## fare vs boarding point

# %%
Fare_survived=data.query("Boarded == 'Southampton' | Boarded == 'Cherbourg' & Survived == 1.0 "  )

# %%
Fare_survived
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1302       0.0       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303       0.0       3                     Henriksson, Miss. Jenny Lovisa
# 1304       0.0       3                                 Spector, Mr. Woolf
# 1306       0.0       3                       Saether, Mr. Simon Sivertsen
# 1307       0.0       3                                Ware, Mr. Frederick
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...
